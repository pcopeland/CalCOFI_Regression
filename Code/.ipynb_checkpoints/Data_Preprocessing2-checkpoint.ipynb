# %%
# Importing required packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
import scipy.stats as stats
from sklearn import preprocessing

# %%
# Reading in data tables from https://calcofi.org/data/oceanographic-data/bottle-database/
df_bottle = pd.read_csv('../data/194903-202101_Bottle.csv', encoding='unicode_escape')
# Out:
# /var/folders/1j/227gtx89455_vcjz4mqv09ch0000gn/T/ipykernel_96909/2762642887.py:2: DtypeWarning: Columns (47,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bottle = pd.read_csv('../data//194903-202101_Bottle.csv', encoding='unicode_escape')

# %%
# Find the number of unique values in 'object' type columns
object_columns = df_bottle.select_dtypes(include=['object']).columns
unique_values_per_object_column = df_bottle[object_columns].nunique()

# Display the number of unique values in 'object' type columns
print("Number of unique values in 'object' type columns:")
print(unique_values_per_object_column)
# Out:
# Number of unique values in 'object' type columns:
# Sta_ID                   2646
# Depth_ID               894458
# IncTim                    203
# DIC Quality Comment        37
# dtype: int64

# %%
bottle = df_bottle.copy()
bottle.dropna(axis='columns', thresh=int(bottle.shape[0]*.80), inplace=True)
bottle.dropna(inplace=True)

# %%
# bottle.to_csv("194903-202101_Bottle2.csv")
int(bottle.shape[0]*.95)
# Out:
# 575826

# %%
df_cast = pd.read_csv('../data/194903-202101_Cast.csv', encoding='unicode_escape')
# Out:
# /var/folders/1j/227gtx89455_vcjz4mqv09ch0000gn/T/ipykernel_96909/4285893817.py:1: DtypeWarning: Columns (38,39,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cast = pd.read_csv('../data/194903-202101_Cast.csv', encoding='unicode_escape')

# %%
# Find the number of unique values in 'object' type columns
object_columns = df_cast.select_dtypes(include=['object']).columns
unique_values_per_object_column = df_cast[object_columns].nunique()

# Display the number of unique values in 'object' type columns
print("Number of unique values in 'object' type columns:")
print(unique_values_per_object_column)
# Out:
# Number of unique values in 'object' type columns:
# Cruise_ID        661
# Cast_ID        35600
# Sta_ID          2634
# Sta_Code           7
# Date            6725
# Time            3877
# Lat_Hem            1
# Lon_Hem            1
# Ship_Name         36
# Ship_Code         34
# Data_Type          5
# Orig_Sta_ID     4190
# Data_Or            5
# Cruz_Num         396
# Inc_Str          120
# Inc_End          203
# PST_LAN           80
# Civil_T          181
# dtype: int64

# %%
df = pd.merge(df_bottle, df_cast)

# %%
df.dropna(axis='columns', thresh=int(bottle.shape[0]*.95), inplace=True)
df.dropna(inplace=True)
df
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 3771        124     3772  092.0 039.0  19-4904NS-HY-088-1948-09200390-0000B-3
# 3772        124     3773  092.0 039.0  19-4904NS-HY-088-1948-09200390-0010A-3
# 3773        124     3774  092.0 039.0  19-4904NS-HY-088-1948-09200390-0020A-7
# 3774        124     3775  092.0 039.0  19-4904NS-HY-088-1948-09200390-0025A-3
# 3775        124     3776  092.0 039.0  19-4904NS-HY-088-1948-09200390-0030A-7
# ...         ...      ...          ...                                     ...
# 817760    32580   817761  070.0 055.0  20-1101NM-MX-031-1553-07000550-0250A-7
# 817762    32580   817763  070.0 055.0  20-1101NM-MX-031-1553-07000550-0300A-7
# 817765    32580   817766  070.0 055.0  20-1101NM-MX-031-1553-07000550-0400A-7
# 817767    32580   817768  070.0 055.0  20-1101NM-MX-031-1553-07000550-0500A-7
# 830772    33073   830773  093.3 028.0  20-1207OS-MX-185-1506-09330280-0000B-7
#
#         Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  Bottom_D  \
# 3771         0   13.86  33.570    5.72  25.112   97.4  ...    1866.0
# 3772        10   13.65  33.420    5.45  25.039   92.3  ...    1866.0
# 3773        20   13.54  33.488    5.58  25.115   94.3  ...    1866.0
# 3774        25   13.51  33.550    5.70  25.169   96.3  ...    1866.0
# 3775        30   13.50  33.556    5.71  25.176   96.5  ...    1866.0
# ...        ...     ...     ...     ...     ...    ...  ...       ...
# 817760     250    8.03  34.108    1.45  26.573   21.8  ...    1339.0
# 817762     300    7.58  34.166    1.12  26.685   16.7  ...    1339.0
# 817765     400    6.95  34.191    0.72  26.794   10.6  ...    1339.0
# 817767     500    6.03  34.255    0.40  26.966    5.7  ...    1339.0
# 830772       0   18.05  33.586    6.40  24.178  118.4  ...     610.0
#
#                Ship_Name  Ship_Code  Data_Type  Event_Num  Orig_Sta_ID  \
# 3771    MV N.B. SCOFIELD       31NS         HY      125.0       092 39
# 3772    MV N.B. SCOFIELD       31NS         HY      125.0       092 39
# 3773    MV N.B. SCOFIELD       31NS         HY      125.0       092 39
# 3774    MV N.B. SCOFIELD       31NS         HY      125.0       092 39
# 3775    MV N.B. SCOFIELD       31NS         HY      125.0       092 39
# ...                  ...        ...        ...        ...          ...
# 817760    RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 817762    RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 817765    RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 817767    RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 830772    RV OCEAN STARR       31OS         MX       12.0    93.3 28.0
#
#         Cruz_Num  Wind_Dir  Wind_Spd  Wea
# 3771        4904      32.0       8.0  4.0
# 3772        4904      32.0       8.0  4.0
# 3773        4904      32.0       8.0  4.0
# 3774        4904      32.0       8.0  4.0
# 3775        4904      32.0       8.0  4.0
# ...          ...       ...       ...  ...
# 817760      1101      26.0      16.0  1.0
# 817762      1101      26.0      16.0  1.0
# 817765      1101      26.0      16.0  1.0
# 817767      1101      26.0      16.0  1.0
# 830772      1207      16.0       5.0  2.0
#
# [296163 rows x 64 columns]

# %%
df.tail(2000)
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 765355    30616   765356  086.7 110.0  20-0407JD-PR-203-1821-08671100-0500A-7
# 765398    30620   765399  090.0 030.0  20-0407JD-MX-200-2210-09000300-0200A-7
# 765400    30620   765401  090.0 030.0  20-0407JD-MX-200-2210-09000300-0250A-7
# 765402    30620   765403  090.0 030.0  20-0407JD-MX-200-2210-09000300-0300A-7
# 765405    30620   765406  090.0 030.0  20-0407JD-MX-200-2210-09000300-0400A-7
# ...         ...      ...          ...                                     ...
# 817760    32580   817761  070.0 055.0  20-1101NM-MX-031-1553-07000550-0250A-7
# 817762    32580   817763  070.0 055.0  20-1101NM-MX-031-1553-07000550-0300A-7
# 817765    32580   817766  070.0 055.0  20-1101NM-MX-031-1553-07000550-0400A-7
# 817767    32580   817768  070.0 055.0  20-1101NM-MX-031-1553-07000550-0500A-7
# 830772    33073   830773  093.3 028.0  20-1207OS-MX-185-1506-09330280-0000B-7
#
#         Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  Bottom_D  \
# 765355     500    5.63  34.155    0.70  26.936   10.0  ...    3935.0
# 765398     200    9.25  34.148    2.08  26.415   32.2  ...     635.0
# 765400     250    8.72  34.184    1.75  26.528   26.8  ...     635.0
# 765402     300    8.50  34.259    1.20  26.621   18.3  ...     635.0
# 765405     400    7.81  34.301    0.70  26.759   10.5  ...     635.0
# ...        ...     ...     ...     ...     ...    ...  ...       ...
# 817760     250    8.03  34.108    1.45  26.573   21.8  ...    1339.0
# 817762     300    7.58  34.166    1.12  26.685   16.7  ...    1339.0
# 817765     400    6.95  34.191    0.72  26.794   10.6  ...    1339.0
# 817767     500    6.03  34.255    0.40  26.966    5.7  ...    1339.0
# 830772       0   18.05  33.586    6.40  24.178  118.4  ...     610.0
#
#                     Ship_Name  Ship_Code  Data_Type  Event_Num  Orig_Sta_ID  \
# 765355  RV DAVID STARR JORDAN       31JD         PR      422.0      87  110
# 765398  RV DAVID STARR JORDAN       31JD         MX      272.0      90   30
# 765400  RV DAVID STARR JORDAN       31JD         MX      272.0      90   30
# 765402  RV DAVID STARR JORDAN       31JD         MX      272.0      90   30
# 765405  RV DAVID STARR JORDAN       31JD         MX      272.0      90   30
# ...                       ...        ...        ...        ...          ...
# 817760         RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 817762         RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 817765         RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 817767         RV NEW HORIZON       32NM         MX      852.0    70.0 55.0
# 830772         RV OCEAN STARR       31OS         MX       12.0    93.3 28.0
#
#         Cruz_Num  Wind_Dir  Wind_Spd  Wea
# 765355      0407      32.0      10.0  1.0
# 765398      0407      24.0       6.0  1.0
# 765400      0407      24.0       6.0  1.0
# 765402      0407      24.0       6.0  1.0
# 765405      0407      24.0       6.0  1.0
# ...          ...       ...       ...  ...
# 817760      1101      26.0      16.0  1.0
# 817762      1101      26.0      16.0  1.0
# 817765      1101      26.0      16.0  1.0
# 817767      1101      26.0      16.0  1.0
# 830772      1207      16.0       5.0  2.0
#
# [2000 rows x 64 columns]

# %%
df.tail(2000).to_csv("../data/ocean0.csv")

# %%
df.tail(2000).to_csv("/Users/Copeland/Library/CloudStorage/GoogleDrive-copelandml@gmail.com/My Drive/School/Masters/2023-2024/Fall/ISYE-6414/final_project/CalCOFI_Regression/data/ocean0.csv")

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------

# %%
df_ocean = pd.read_csv('../data/ocean0.csv', index_col=0)
df_ocean.head()
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 765355    30616   765356  086.7 110.0  20-0407JD-PR-203-1821-08671100-0500A-7
# 765398    30620   765399  090.0 030.0  20-0407JD-MX-200-2210-09000300-0200A-7
# 765400    30620   765401  090.0 030.0  20-0407JD-MX-200-2210-09000300-0250A-7
# 765402    30620   765403  090.0 030.0  20-0407JD-MX-200-2210-09000300-0300A-7
# 765405    30620   765406  090.0 030.0  20-0407JD-MX-200-2210-09000300-0400A-7
#
#         Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  Bottom_D  \
# 765355     500    5.63  34.155    0.70  26.936   10.0  ...    3935.0
# 765398     200    9.25  34.148    2.08  26.415   32.2  ...     635.0
# 765400     250    8.72  34.184    1.75  26.528   26.8  ...     635.0
# 765402     300    8.50  34.259    1.20  26.621   18.3  ...     635.0
# 765405     400    7.81  34.301    0.70  26.759   10.5  ...     635.0
#
#                     Ship_Name  Ship_Code  Data_Type  Event_Num  Orig_Sta_ID  \
# 765355  RV DAVID STARR JORDAN       31JD         PR      422.0      87  110
# 765398  RV DAVID STARR JORDAN       31JD         MX      272.0      90   30
# R_Depth        3.020000e+02  4.030000e+02  1.009000e+03
# R_Temp         7.500000e+00  8.270000e+00  1.805000e+01
# R_Sal          1.404500e+02  1.527000e+02  3.778000e+02
# R_DYNHT        6.700000e-01  8.182500e-01  1.353000e+00
# R_Oxy_µmol/Kg  5.350084e+01  8.352949e+01  2.790765e+02
# Cruise         2.006040e+05  2.007040e+05  2.012070e+05
# Cruz_Sta       2.006041e+13  2.007041e+13  2.012071e+13
# DbSta_ID       8.670900e+06  9.001200e+06  9.331200e+06
# Quarter        3.000000e+00  4.000000e+00  4.000000e+00
# Year           2.006000e+03  2.007000e+03  2.012000e+03
# Month          7.000000e+00  1.000000e+01  1.100000e+01
# Julian_Date    3.881950e+04  3.917000e+04  4.109300e+04
# Julian_Day     1.850000e+02  2.960000e+02  3.240000e+02
# Lat_Dec        3.267333e+01  3.349167e+01  3.761500e+01
# Lat_Deg        3.200000e+01  3.300000e+01  3.700000e+01
# Lat_Min        2.900000e+01  4.340000e+01  5.960000e+01
# Lon_Dec       -1.214433e+02 -1.195662e+02 -1.173917e+02
# Lon_Deg       -1.210000e+02 -1.190000e+02 -1.170000e+02
# Lon_Min        3.320000e+01  5.040000e+01  5.990000e+01
# Rpt_Line       8.670000e+01  9.000000e+01  9.330000e+01
# St_Line        8.670000e+01  9.000000e+01  9.330000e+01
# Ac_Line        8.670000e+01  9.000000e+01  9.340000e+01
# Rpt_Sta        7.000000e+01  9.000000e+01  1.200000e+02
# St_Station     7.000000e+01  9.000000e+01  1.200000e+02
# Ac_Sta         7.000000e+01  9.000000e+01  1.203000e+02
# Bottom_D       3.692000e+03  4.072750e+03  4.596000e+03
# Event_Num      3.620000e+02  5.445000e+02  1.142000e+03
# Cruz_Num       6.040000e+02  7.040000e+02  1.207000e+03
# Wind_Dir       3.100000e+01  3.300000e+01  3.600000e+01
# Wind_Spd       1.100000e+01  1.700000e+01  3.500000e+01
# Wea            1.000000e+00  2.000000e+00  6.000000e+00

# %%
df_ocean.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'RecInd',
#        'T_prec', 'S_prec', 'P_qual', 'Chlqua', 'Phaqua', 'NH3q', 'C14A1q',
#        'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_Temp', 'R_Sal', 'R_DYNHT',
#        'R_Oxy_µmol/Kg', 'Cruise_ID', 'Cruise', 'Cruz_Sta', 'DbSta_ID',
#        'Cast_ID', 'Quarter', 'Sta_Code', 'Date', 'Year', 'Month',
#        'Julian_Date', 'Julian_Day', 'Time', 'Lat_Dec', 'Lat_Deg', 'Lat_Min',
#        'Lat_Hem', 'Lon_Dec', 'Lon_Deg', 'Lon_Min', 'Lon_Hem', 'Rpt_Line',
#        'St_Line', 'Ac_Line', 'Rpt_Sta', 'St_Station', 'Ac_Sta', 'Bottom_D',
#        'Ship_Name', 'Ship_Code', 'Data_Type', 'Event_Num', 'Orig_Sta_ID',
#        'Cruz_Num', 'Wind_Dir', 'Wind_Spd', 'Wea'],
#       dtype='object')

# %%
columns_with_same_value = [col for col in df_ocean.columns if df_ocean[col].nunique() == 1]

# Display columns with the same value for all data points
print("Columns with the same value for all data points:")
print(columns_with_same_value)
# Out:
# Columns with the same value for all data points:
# ['T_prec', 'S_prec', 'Chlqua', 'Phaqua', 'NH3q', 'C14A1q', 'C14A2q', 'DarkAq', 'MeanAq', 'Lat_Hem', 'Lon_Hem']

# %%
selected_columns = ['Salnty'] + [col for col in df_ocean.columns if col != 'Salnty']
subset_df = df_ocean[selected_columns]
subset_df = subset_df.drop(columns=columns_with_same_value)

object_list = ['Cruise', 'Cruz_Sta', 'DbSta_ID', 'Quarter', 'Wea', 'Year', 'Month', 'Julian_Date', 'Julian_Day']
subset_df[object_list] = subset_df[object_list].astype("object")
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 765355 to 830772
# Data columns (total 53 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Salnty         2000 non-null   float64
#  1   Cst_Cnt        2000 non-null   int64
#  2   Btl_Cnt        2000 non-null   int64
#  3   Sta_ID         2000 non-null   object
#  4   Depth_ID       2000 non-null   object
#  5   Depthm         2000 non-null   int64
#  6   T_degC         2000 non-null   float64
#  7   O2ml_L         2000 non-null   float64
#  8   STheta         2000 non-null   float64
#  9   O2Sat          2000 non-null   float64
#  10  Oxy_µmol/Kg    2000 non-null   float64
#  11  RecInd         2000 non-null   int64
#  12  P_qual         2000 non-null   float64
#  13  R_Depth        2000 non-null   float64
#  14  R_Temp         2000 non-null   float64
#  15  R_Sal          2000 non-null   float64
#  16  R_DYNHT        2000 non-null   float64
#  17  R_Oxy_µmol/Kg  2000 non-null   float64
#  18  Cruise_ID      2000 non-null   object
#  19  Cruise         2000 non-null   object
#  20  Cruz_Sta       2000 non-null   object
#  21  DbSta_ID       2000 non-null   object
#  22  Cast_ID        2000 non-null   object
#  23  Quarter        2000 non-null   object
#  24  Sta_Code       2000 non-null   object
#  25  Date           2000 non-null   object
#  26  Year           2000 non-null   object
#  27  Month          2000 non-null   object
#  28  Julian_Date    2000 non-null   object
#  29  Julian_Day     2000 non-null   object
#  30  Time           2000 non-null   object
#  31  Lat_Dec        2000 non-null   float64
#  32  Lat_Deg        2000 non-null   int64
#  33  Lat_Min        2000 non-null   float64
#  34  Lon_Dec        2000 non-null   float64
#  35  Lon_Deg        2000 non-null   int64
#  36  Lon_Min        2000 non-null   float64
#  37  Rpt_Line       2000 non-null   float64
#  38  St_Line        2000 non-null   float64
#  39  Ac_Line        2000 non-null   float64
#  40  Rpt_Sta        2000 non-null   float64
#  41  St_Station     2000 non-null   float64
#  42  Ac_Sta         2000 non-null   float64
#  43  Bottom_D       2000 non-null   float64
#  44  Ship_Name      2000 non-null   object
#  45  Ship_Code      2000 non-null   object
#  46  Data_Type      2000 non-null   object
#  47  Event_Num      2000 non-null   float64
#  48  Orig_Sta_ID    2000 non-null   object
#  49  Cruz_Num       2000 non-null   int64
#  50  Wind_Dir       2000 non-null   float64
#  51  Wind_Spd       2000 non-null   float64
#  52  Wea            2000 non-null   object
# dtypes: float64(26), int64(7), object(20)
# memory usage: 908.3+ KB

# %%
corr = subset_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_
{
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_e018b_row1_col5, #T_e018b_row1_col8, #T_e018b_row1_col15, #T_e018b_row2_col5, #T_e018b_row2_col8, #T_e018b_row2_col15, #T_e018b_row25_col6, #T_e018b_row26_col6, #T_e018b_row27_col6, #T_e018b_row30_col5, #T_e018b_row30_col8, #T_e018b_row30_col15 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_e018b_row1_col6, #T_e018b_row2_col6, #T_e018b_row13_col25, #T_e018b_row13_col26, #T_e018b_row13_col27, #T_e018b_row17_col20, #T_e018b_row30_col6 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_e018b_row1_col7, #T_e018b_row2_col7, #T_e018b_row3_col28, #T_e018b_row9_col16, #T_e018b_row10_col16, #T_e018b_row11_col28, #T_e018b_row22_col3, #T_e018b_row22_col11, #T_e018b_row23_col3, #T_e018b_row23_col11, #T_e018b_row24_col3, #T_e018b_row24_col11, #T_e018b_row30_col7, #T_e018b_row30_col14 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_e018b_row1_col9, #T_e018b_row1_col10, #T_e018b_row3_col7, #T_e018b_row3_col8, #T_e018b_row3_col15, #T_e018b_row11_col7, #T_e018b_row29_col31, #T_e018b_row30_col21 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e018b_row1_col13, #T_e018b_row2_col13, #T_e018b_row3_col16, #T_e018b_row3_col19, #T_e018b_row3_col22, #T_e018b_row3_col23, #T_e018b_row3_col24, #T_e018b_row9_col20, #T_e018b_row9_col25, #T_e018b_row9_col26, #T_e018b_row9_col27, #T_e018b_row10_col20, #T_e018b_row10_col25, #T_e018b_row10_col26, #T_e018b_row10_col27, #T_e018b_row11_col16, #T_e018b_row11_col19, #T_e018b_row11_col22, #T_e018b_row11_col23, #T_e018b_row11_col24, #T_e018b_row13_col28, #T_e018b_row20_col3, #T_e018b_row20_col11, #T_e018b_row21_c

# %%
correlation_matrix = subset_df.corr()

# Create a heatmap using seaborn
plt.figure(figsize=(20, 1))
sns.heatmap(correlation_matrix[['Salnty']].transpose(), annot=True, cmap='coolwarm', fmt=".2f", cbar=False)
plt.title('Correlation Heatmap for Salnty')
plt.show()

# %%
correlation_with_salnty = correlation_matrix['Salnty']

correlation_df = pd.DataFrame(correlation_with_salnty.items(), columns=['Column', 'Correlation_with_Salnty'])
correlation_df = correlation_df.sort_values(by='Correlation_with_Salnty', ascending=False).reset_index()
correlation_df
# Out:
#     index         Column  Correlation_with_Salnty
# 0       0         Salnty                 1.000000
# 1       6         STheta                 0.833721
# 2      11        R_Depth                 0.655772
# 3       3         Depthm                 0.655432
# 4      19        Lon_Dec                 0.454412
# 5      20        Lon_Deg                 0.445338
# 6      14        R_DYNHT                 0.443220
# 7       9         RecInd                 0.186955
# 8      10         P_qual                 0.186955
# 9      17        Lat_Deg                 0.186010
# 10     16        Lat_Dec                 0.184023
# 11     24        Ac_Line                 0.107631
# 12     22       Rpt_Line                 0.107400
# 13     23        St_Line                 0.107400
# 14      1        Cst_Cnt                 0.037209
# 15      2        Btl_Cnt                 0.036976
# 16     30       Cruz_Num                 0.036447
# 17     21        Lon_Min                -0.014323
# 18     18        Lat_Min                -0.018205
# 19     31       Wind_Dir                -0.047040
# 20     29      Event_Num                -0.117933
# 21     32       Wind_Spd                -0.175145
# 22     28       Bottom_D                -0.399204
# 23     27         Ac_Sta                -0.466394
# 24     25        Rpt_Sta                -0.466605
# 25     26     St_Station                -0.466611
# 26      4         T_degC                -0.601500
# 27     12         R_Temp                -0.603048
# 28     13          R_Sal                -0.831290
# 29      5         O2ml_L                -0.913474
# 30     15  R_Oxy_µmol/Kg                -0.913574
# 31      8    Oxy_µmol/Kg                -0.913574
# 32      7          O2Sat                -0.915151

# %%
# drop_df = correlation_df[abs(correlation_df.Correlation_with_Salnty) < 0.1]
# drop_list = drop_df['Column'].tolist()

# new_df = subset_df.drop(columns=drop_list)

# %%
new_df = subset_df.drop(['Sta_ID', 'Depth_ID', 'Ship_Name', 'Cruise_ID', 'Cruise', 'Cruz_Sta', 'DbSta_ID', 
                         'Cast_ID', 'Sta_Code', 'Date', 'Ship_Code', 'Data_Type', 'Orig_Sta_ID', 'Quarter', 
                         'Julian_Date', 'Julian_Day', 'Time', 'Btl_Cnt', 'Lat_Min', 'Rpt_Sta', 'St_Station', 
                         'Ac_Sta', 'R_DYNHT', 'Cst_Cnt', 'Lat_Deg', 'Rpt_Line', 'St_Line', 'Ac_Line',  
                         'Cruz_Num', 'Event_Num', 'RecInd', 'Lat_Dec', 'P_qual', 'Lon_Dec', 'Lon_Deg', 
                         'Lon_Min', 'Wind_Dir', 'Wind_Spd'], axis=1)

new_df = new_df.drop(['R_Depth', 'R_Temp', 'R_Sal', 'R_Oxy_µmol/Kg'], axis=1)

new_df
# Out:
#         Salnty  Depthm  T_degC  O2ml_L  STheta  O2Sat  Oxy_µmol/Kg  Year  \
# 765355  34.155     500    5.63    0.70  26.936   10.0     30.44201  2004
# 765398  34.148     200    9.25    2.08  26.415   32.2     90.50218  2004
# 765400  34.184     250    8.72    1.75  26.528   26.8     76.13528  2004
# 765402  34.259     300    8.50    1.20  26.621   18.3     52.20232  2004
# 765405  34.301     400    7.81    0.70  26.759   10.5     30.44726  2004
# ...        ...     ...     ...     ...     ...    ...          ...   ...
# 817760  34.108     250    8.03    1.45  26.573   21.8     63.08076  2011
# 817762  34.166     300    7.58    1.12  26.685   16.7     48.71913  2011
# 817765  34.191     400    6.95    0.72  26.794   10.6     31.31612  2011
# 817767  34.255     500    6.03    0.40  26.966    5.7     17.39493  2011
# 830772  33.586       0   18.05    6.40  24.178  118.4    279.07650  2012
#
#        Month  Bottom_D  Wea
# 765355     7    3935.0  1.0
# 765398     7     635.0  1.0
# 765400     7     635.0  1.0
# 765402     7     635.0  1.0
# 765405     7     635.0  1.0
# ...      ...       ...  ...
# 817760     1    1339.0  1.0
# 817762     1    1339.0  1.0
# 817765     1    1339.0  1.0
# 817767     1    1339.0  1.0
# 830772     7     610.0  2.0
#
# [2000 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# set figure size
plt.figure(figsize=(30, 30))

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(new_df.corr(), dtype=bool))

# generate heatmap
sns.heatmap(new_df.corr(), annot=True, mask=mask, vmin=-1, vmax=1)
plt.title('Correlation Coefficient Of Predictors')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

def compute_vif(considered_features):
    
    X = new_df[considered_features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

considered_features = new_df.columns
compute_vif(considered_features).sort_values('VIF', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1j/227gtx89455_vcjz4mqv09ch0000gn/T/ipykernel_96909/1369013472.py in <module>
#      16
#      17 considered_features = new_df.columns
# ---> 18 compute_vif(considered_features).sort_values('VIF', ascending=False)
#
# /var/folders/1j/227gtx89455_vcjz4mqv09ch0000gn/T/ipykernel_96909/1369013472.py in compute_vif(considered_features)
#      11     vif = pd.DataFrame()
#      12     vif["Variable"] = X.columns
# ---> 13     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#      14     vif = vif[vif['Variable']!='intercept']
#      15     return vif
#
# /var/folders/1j/227gtx89455_vcjz4mqv09ch0000gn/T/ipykernel_96909/1369013472.py in <listcomp>(.0)
#      11     vif = pd.DataFrame()
#      12     vif["Variable"] = X.columns
# ---> 13     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#      14     vif = vif[vif['Variable']!='intercept']
#      15     return vif
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/stats/outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     192     mask = np.arange(k_vars) != exog_idx
#     193     x_noti = exog[:, mask]
# --> 194     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     195     vif = 1. / (1. - r_squared_i)
#     196     return vif
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     888                    "An exception will be raised in the next version.")
#     889             warnings.warn(msg, ValueWarning)
# --> 890         super(OLS, self).__init__(endog, exog, missing=missing,
#     891                                   hasconst=hasconst, **kwargs)
#     892         if "weights" in self._init_keys:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     715         else:
#     716             weights = weights.squeeze()
# --> 717         super(WLS, self).__init__(endog, exog, missing=missing,
#     718                                   weights=weights, hasconst=hasconst, **kwargs)
#     719         nobs = self.exog.shape[0]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     189     """
#     190     def __init__(self, endog, exog, **kwargs):
# --> 191         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     192         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     193
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     265
#     266     def __init__(self, endog, exog=None, **kwargs):
# --> 267         super().__init__(endog, exog, **kwargs)
#     268         self.initialize()
#     269
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      90         missing = kwargs.pop('missing', 'none')
#      91         hasconst = kwargs.pop('hasconst', None)
# ---> 92         self.data = self._handle_data(endog, exog, missing, hasconst,
#      93                                       **kwargs)
#      94         self.k_constant = self.data.k_constant
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     130
#     131     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133         # kwargs arrays could have changed, easier to just attach here
#     134         for key in kwargs:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     671
#     672     klass = handle_data_class_factory(endog, exog)
# --> 673     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     674                  **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      84         self.const_idx = None
#      85         self.k_constant = 0
# ---> 86         self._handle_constant(hasconst)
#      87         self._check_integrity()
#      88         self._cache = {}
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/data.py in _handle_constant(self, hasconst)
#     129             check_implicit = False
#     130             exog_max = np.max(self.exog, axis=0)
# --> 131             if not np.isfinite(exog_max).all():
#     132                 raise MissingDataError('exog contains inf or nans')
#     133             exog_min = np.min(self.exog, axis=0)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# Find the number of unique values in 'object' type columns
object_columns = new_df.select_dtypes(include=['object']).columns
unique_values_per_object_column = new_df[object_columns].nunique()

# Display the number of unique values in 'object' type columns
print("Number of unique values in 'object' type columns:")
print(unique_values_per_object_column)
# Out:
# Number of unique values in 'object' type columns:
# Year      9
# Month    10
# Wea       6
# dtype: int64

# %%
new_df.to_csv("/Users/Copeland/Library/CloudStorage/GoogleDrive-copelandml@gmail.com/My Drive/School/Masters/2023-2024/Fall/ISYE-6414/final_project/CalCOFI_Regression/data/ocean1.csv")

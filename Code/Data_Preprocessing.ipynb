# %% [markdown]
# ### Simple, Multiple, and Logistic Regression Analysis on CalCOFI oceanographic data

# %%
# Importing required packages
import pandas as pd

# %%
# Reading in data tables from https://calcofi.org/data/oceanographic-data/bottle-database/
df_bottle = pd.read_csv('CalCOFI_Database/194903-202101_Bottle.csv', encoding='unicode_escape')
df_bottle
# Out:
# C:\Users\copel\AppData\Local\Temp\ipykernel_7968\1879365886.py:2: DtypeWarning: Columns (47,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bottle = pd.read_csv('CalCOFI_Database/194903-202101_Bottle.csv', encoding='unicode_escape')
#         Cst_Cnt  Btl_Cnt        Sta_ID  \
# 0             1        1   054.0 056.0
# 1             1        2   054.0 056.0
# 2             1        3   054.0 056.0
# 3             1        4   054.0 056.0
# 4             1        5   054.0 056.0
# ...         ...      ...           ...
# 894475    35599   894476  093.3 0120.0
# 894476    35599   894477  093.3 0120.0
# 894477    35600   894478   093.4 026.4
# 894478    35600   894479   093.4 026.4
# 894479    35600   894480   093.4 026.4
#
#                                       Depth_ID  Depthm  T_degC   Salnty  \
# 0       19-4903CR-HY-060-0930-05400560-0000A-3       0  10.500  33.4400
# 1       19-4903CR-HY-060-0930-05400560-0008A-3       8  10.460  33.4400
# ...

# %%
bottle = df_bottle.copy()
bottle.dropna(axis='columns', thresh=int(bottle.shape[0]*.80), inplace=True)
bottle.dropna(inplace=True)
bottle
# Out:
#         Cst_Cnt  Btl_Cnt        Sta_ID  \
# 2160         71     2161   044.0 048.5
# 2162         71     2163   044.0 048.5
# 2163         71     2164   044.0 048.5
# 2164         71     2165   044.0 048.5
# 2165         71     2166   044.0 048.5
# ...         ...      ...           ...
# 894473    35599   894474  093.3 0120.0
# 894474    35599   894475  093.3 0120.0
# 894475    35599   894476  093.3 0120.0
# 894476    35599   894477  093.3 0120.0
# 894478    35600   894479   093.4 026.4
#
#                                       Depth_ID  Depthm  T_degC   Salnty  \
# 2160    19-4904CR-HY-087-0606-04400485-0000B-3       0  10.300  33.0300
# 2162    19-4904CR-HY-087-0606-04400485-0010A-7      10  10.290  32.9510
# 2163    19-4904CR-HY-087-0606-04400485-0015A-3      15  10.290  32.9900
# 2164    19-4904CR-HY-087-0606-04400485-0020A-7      20  10.330  33.0050
# 2165    19-4904CR-HY-087-0606-04400485-0030A-7      30  10.390  33.0540
# ...

# %%
# bottle.to_csv("194903-202101_Bottle2.csv")
int(bottle.shape[0]*.95)
# Out:
# 718484

# %%
df_cast = pd.read_csv('CalCOFI_Database/194903-202101_Cast.csv', encoding='unicode_escape')
df_cast.head()
# df_cast.describe()
# Out:
# C:\Users\copel\AppData\Local\Temp\ipykernel_7968\409792041.py:1: DtypeWarning: Columns (38,39,42,43,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cast = pd.read_csv('CalCOFI_Database/194903-202101_Cast.csv', encoding='unicode_escape')
#    Cst_Cnt          Cruise_ID  Cruise        Cruz_Sta  DbSta_ID  \
# 0        1  1949-03-01-C-31CR  194903  19490305400560   5400560
# 1        2  1949-03-01-C-31CR  194903  19490305200750   5200750
# 2        3  1949-03-01-C-31CR  194903  19490305100850   5100850
# 3        4  1949-03-01-C-31CR  194903  19490305000950   5000950
# 4        5  1949-03-01-C-31CR  194903  19490305001040   5001040
#
#                           Cast_ID       Sta_ID  Quarter Sta_Code  Distance  \
# 0  19-4903CR-HY-060-0930-05400560  054.0 056.0        1      NST       NaN
# 1  19-4903CR-HY-060-2112-05200750  052.0 075.0        1      NST       NaN
# 2  19-4903CR-HY-061-0354-05100850  051.0 085.0        1      NST       NaN
# ...

# %%
df = pd.merge(df_bottle, df_cast)
# df = df.astype({"Year": 'int'})
df
# df.nunique()
# df.dtypes
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0             1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1             1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2             1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3             1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4             1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ...         ...      ...          ...                                     ...
# 893590    35596   894405  093.3 090.0  20-2101RL-MX-018-1206-09330900-0500A-7
# 893591    35596   894406  093.3 090.0  20-2101RL-MX-018-1206-09330900-0517A-3
# 893592    35600   894478  093.4 026.4  20-2101RL-MX-016-0746-09340264-0000A-7
# 893593    35600   894479  093.4 026.4  20-2101RL-MX-016-0746-09340264-0002A-3
# 893594    35600   894480  093.4 026.4  20-2101RL-MX-016-0746-09340264-0009A-3
#
# ...

# %%
df.dropna(axis='columns', thresh=int(bottle.shape[0]*.80), inplace=True)# df = df.dropna()
df.dropna(inplace=True)
df
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 375187    13972   375188  093.3 028.0  19-6404AX-HY-102-0342-09330280-0000B-3
# 375188    13972   375189  093.3 028.0  19-6404AX-HY-102-0342-09330280-0010A-3
# 375189    13972   375190  093.3 028.0  19-6404AX-HY-102-0342-09330280-0020A-7
# 375190    13972   375191  093.3 028.0  19-6404AX-HY-102-0342-09330280-0030A-3
# 375191    13972   375192  093.3 028.0  19-6404AX-HY-102-0342-09330280-0045A-3
# ...         ...      ...          ...                                     ...
# 817760    32580   817761  070.0 055.0  20-1101NM-MX-031-1553-07000550-0250A-7
# 817762    32580   817763  070.0 055.0  20-1101NM-MX-031-1553-07000550-0300A-7
# 817765    32580   817766  070.0 055.0  20-1101NM-MX-031-1553-07000550-0400A-7
# 817767    32580   817768  070.0 055.0  20-1101NM-MX-031-1553-07000550-0500A-7
# 830772    33073   830773  093.3 028.0  20-1207OS-MX-185-1506-09330280-0000B-7
#
# ...

# %%
df.tail(5000)
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 401500    15055   401501  086.7 080.0  19-6612JD-HY-343-0836-08670800-0000B-3
# 401501    15055   401502  086.7 080.0  19-6612JD-HY-343-0836-08670800-0010A-3
# 401503    15055   401504  086.7 080.0  19-6612JD-HY-343-0836-08670800-0030A-3
# 401505    15055   401506  086.7 080.0  19-6612JD-HY-343-0836-08670800-0061A-3
# 401506    15055   401507  086.7 080.0  19-6612JD-HY-343-0836-08670800-0069A-3
# ...         ...      ...          ...                                     ...
# 817760    32580   817761  070.0 055.0  20-1101NM-MX-031-1553-07000550-0250A-7
# 817762    32580   817763  070.0 055.0  20-1101NM-MX-031-1553-07000550-0300A-7
# 817765    32580   817766  070.0 055.0  20-1101NM-MX-031-1553-07000550-0400A-7
# 817767    32580   817768  070.0 055.0  20-1101NM-MX-031-1553-07000550-0500A-7
# 830772    33073   830773  093.3 028.0  20-1207OS-MX-185-1506-09330280-0000B-7
#
# ...

# %%
df.tail(5000).to_csv("df.csv")
